# %%
from pycaret.classification import *
import pandas as pd

# %%
# !pwd
# Out:
# /Users/d.e.magno/Projects/Price Pattern

# %%
df = pd.read_csv('merged_patterns.csv').drop('Unnamed: 0', axis=1)

# %%
df_copy = df.copy(deep=True)

# %%
df_copy = df_copy.filter(['f1', 'f2', 'f3', 'f4', 'f5', 'label'])

# %%
exp_name = setup(data=df_copy, target='label',
                 normalize=True, normalize_method='zscore')
# Out:
# <style  type="text/css" >
# #T_23b8ca34_a08a_11eb_885c_38f9d3416b75row29_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_23b8ca34_a08a_11eb_885c_38f9d3416b75" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23b8ca34_a08a_11eb_885c_38f9d3416b75level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_23b8ca34_a08a_11eb_885c_38f9d3416b75row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_23b8ca34_a08a_11eb_885c_38f9d3416b75row0_col1" class="data row0 col1" >6019</td>
#             </tr>
#             <tr>
#                         <th id="T_23b8ca34_a08a_11eb_885c_38f9d3416b75level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
best_model = compare_models(fold=5)
# Out:
# <style  type="text/css" >
#     #T_489f82b4_a08a_11eb_b1f0_38f9d3416b75 th {
#           text-align: left;
# ...

# %%
best_model
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=1932, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
lightgbm = create_model('lightgbm')
# Out:
# <style  type="text/css" >
# #T_20018b0a_a089_11eb_abc2_38f9d3416b75row10_col0,#T_20018b0a_a089_11eb_abc2_38f9d3416b75row10_col1,#T_20018b0a_a089_11eb_abc2_38f9d3416b75row10_col2,#T_20018b0a_a089_11eb_abc2_38f9d3416b75row10_col3,#T_20018b0a_a089_11eb_abc2_38f9d3416b75row10_col4,#T_20018b0a_a089_11eb_abc2_38f9d3416b75row10_col5,#T_20018b0a_a089_11eb_abc2_38f9d3416b75row10_col6{
#             background:  yellow;
#         }</style><table id="T_20018b0a_a089_11eb_abc2_38f9d3416b75" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tune_model(lightgbm, n_iter=200, choose_better=True)
# Out:
# <style  type="text/css" >
# #T_476ab3cc_a089_11eb_947c_38f9d3416b75row10_col0,#T_476ab3cc_a089_11eb_947c_38f9d3416b75row10_col1,#T_476ab3cc_a089_11eb_947c_38f9d3416b75row10_col2,#T_476ab3cc_a089_11eb_947c_38f9d3416b75row10_col3,#T_476ab3cc_a089_11eb_947c_38f9d3416b75row10_col4,#T_476ab3cc_a089_11eb_947c_38f9d3416b75row10_col5,#T_476ab3cc_a089_11eb_947c_38f9d3416b75row10_col6{
#             background:  yellow;
#         }</style><table id="T_476ab3cc_a089_11eb_947c_38f9d3416b75" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...
